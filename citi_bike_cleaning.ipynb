# %%
import pandas as pd
import glob
import os

# %%
path = r'C:\Users\tmkez\Desktop\homework\tableau-challenge\data'
all_files = glob.glob(os.path.join(path, "*.csv"))

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
concatenated_df.to_csv("C:/Users/tmkez/Desktop/homework/tableau-challenge/data/combined_tripdata_2020.csv")

# %%
concatenated_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
concatenated_df[concatenated_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender]
# Index: []

# %%
start_df = concatenated_df.groupby("start station id").count()

# %%
clean_start = pd.DataFrame(start_df["tripduration"]).reset_index()

# %%
clean_start
# Out:
#      start station id  tripduration
# 0                  72         19800
# 1                  79          7387
# 2                  82          5211
# 3                  83          8073
# 4                 116         21706
# ..                ...           ...
# 968              4021           170
# 969              4023           999
# 970              4036           554
# 971              4037           448
# 972              4038           221
#
# [973 rows x 2 columns]

# %%
end_df = concatenated_df.groupby("end station id").count()

# %%
clean_end = pd.DataFrame(end_df["tripduration"]).reset_index()

# %%
clean_end.loc[clean_end['end station id'] == 426]
# Out:
#      end station id  tripduration
# 171             426         39799

# %%
# df1.merge(df2, left_on='lkey', right_on='rkey')
combined_flow = clean_start.merge(clean_end, left_on='start station id', right_on='end station id')

# %%
combined_flow = combined_flow.drop(['end station id'], axis=1)

# %%
combined_flow = combined_flow.rename(columns={"start station id": "Station ID", "tripduration_x": "Originating Trips", 
                              "tripduration_y": "Ending Trips"})

# %%
combined_flow["Flow"] = combined_flow['Ending Trips'] - combined_flow['Originating Trips']

# %%
combined_flow
# Out:
#      Station ID  Originating Trips  Ending Trips  Flow
# 0            72              19800         19810    10
# 1            79               7387          7504   117
# 2            82               5211          5243    32
# 3            83               8073          8251   178
# 4           116              21706         21704    -2
# ..          ...                ...           ...   ...
# 968        4021                170           160   -10
# 969        4023                999          1002     3
# 970        4036                554           570    16
# 971        4037                448           458    10
# 972        4038                221           206   -15
#
# [973 rows x 4 columns]

# %%
combined_flow.loc[combined_flow['Station ID'] == 514]
# Out:
#      Station ID  Originating Trips  Ending Trips  Flow
# 240         514              38657         40254  1597

# %%
concatenated_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
concatenated_df[['start station id', 'start station latitude', 'start station longitude']]\
.drop_duplicates('start station id').loc[concatenated_df['start station id'] == 514]
# Out:
#    start station id  start station latitude  start station longitude
# 7               514               40.760875               -74.002777

# %%
flow_df = combined_flow.merge(concatenated_df[['start station id', 'start station name', 'start station latitude', 'start station longitude']].drop_duplicates('start station id'), 
                    left_on='Station ID', right_on='start station id')[['Station ID',
                                                                        'start station name',
                                                                        'Flow',
                                                                        'start station latitude',
                                                                        'start station longitude']]
#.loc[concatenated_df['Station ID'] == 514]

# %%
#Positive Flow means the station took IN more bikes than it sent out
#Negative Flow means the station sent OUT more bikes than it took in

#flow_df.loc[flow_df['Station ID'] == 514]
flow_df
# Out:
#      Station ID                   start station name  Flow  \
# 0            72                     W 52 St & 11 Ave    10
# 1            79             Franklin St & W Broadway   117
# 2            82               St James Pl & Pearl St    32
# 3            83        Atlantic Ave & Fort Greene Pl   178
# 4           116                      W 17 St & 8 Ave    -2
# ..          ...                                  ...   ...
# 968        4021           E 138 St & Grand Concourse   -10
# 969        4023  Adam Clayton Powell Blvd & W 141 St     3
# 970        4036                            Motorgate    16
# 971        4037             Roosevelt Island Tramway    10
# 972        4038                      Southpoint Park   -15
#
#      start station latitude  start station longitude
# 0                 40.767272               -73.993929
# 1                 40.719116               -74.006667
# 2                 40.711174               -74.000165
# ...

# %%
flow_df.to_csv("C:/Users/tmkez/Desktop/homework/tableau-challenge/data/station_flow.csv")
